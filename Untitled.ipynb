# %%
import unittest
import read, copy
from logical_classes import *
from student_code import KnowledgeBase

class KBTest(unittest.TestCase):

    def setUp(self):
        # Assert starter facts
        file = 'statements_kb.txt'
#         file2 = 'statements_kb2.txt'
#         file3 = 'statements_kb3.txt'
        data = read.read_tokenize(file)
#         data2 = read.read_tokenize(file2)
#         data3 = read.read_tokenize(file3)
        self.KB = KnowledgeBase([], [])
        for item in data:
            if isinstance(item, Fact):
                self.KB.kb_assert(item)
        self.KB.kb_assert(read.parse_input("hehe: (color bigbox red)"))
        for item in self.KB.facts:
            print(item)
#         for item in data2:
#             if isinstance(item, Fact):
#                 self.KB.kb_assert(item)
#         for item in data3:
#             if isinstance(item, Fact):
#                 self.KB.kb_assert(item)

    def test1(self):
        ask1 = read.parse_input("fact: (color bigbox red)")
        print(' Asking if', ask1)
        answer = self.KB.kb_ask(ask1)
        self.assertEqual(answer[0].bindings, [])
        #self.assertEqual(answer.list_of_bindings[0][1][0], ask1)

    def test2(self):
        ask1 = read.parse_input("fact: (color littlebox red)")
        print(' Asking if', ask1)
        answer = self.KB.kb_ask(ask1)
        self.assertFalse(answer)

    def test3(self):
        ask1 = read.parse_input("fact: (color ?X red)")
        print(' Asking if', ask1)
        answer = self.KB.kb_ask(ask1)
        self.assertEqual(str(answer[0]), "?X : bigbox")
        self.assertEqual(str(answer[1]), "?X : pyramid3")
        self.assertEqual(str(answer[2]), "?X : pyramid4")
        

    def test4(self):
        ask1 = read.parse_input("fact: (color bigbox ?Y)")
        print(' Asking if', ask1)
        answer = self.KB.kb_ask(ask1)
        self.assertEqual(str(answer[0]), "?Y : red")

    def test5(self):
        ask1 = read.parse_input("fact: (color ?X ?Y)")
        print(' Asking if', ask1)
        answer = self.KB.kb_ask(ask1)
        self.assertEqual(str(answer[0]), "?X : bigbox, ?Y : red")
        self.assertEqual(str(answer[1]), "?X : littlebox, ?Y : blue")
        self.assertEqual(str(answer[2]), "?X : pyramid1, ?Y : blue")
        self.assertEqual(str(answer[3]), "?X : pyramid2, ?Y : green")
        self.assertEqual(str(answer[4]), "?X : pyramid3, ?Y : red")
        self.assertEqual(str(answer[5]), "?X : pyramid4, ?Y : red")

#     def test6(self):
#         ask1 = read.parse_input("fact: (hero ?X)")
#         print(' Asking if', ask1)
#         answer = self.KB.kb_ask(ask1)
#         self.assertEqual(str(answer[0]), "?X : Ai")
        
#     def test7(self):
#         ask1 = read.parse_input("fact: (inst Nosliw ?Y)")
#         print(' Asking if', ask1)
#         answer = self.KB.kb_ask(ask1)
#         self.assertEqual(str(answer[0]), "?Y : Dragon")
        
#     def test8(self):
#         ask1 = read.parse_input("fact: (inst ?X dragon)")
#         print(' Asking if', ask1)
#         answer = self.KB.kb_ask(ask1)
#         self.assertEqual(str(answer[0]), "?X : Nosliw")
#         self.assertEqual(str(answer[1]), "?X : Uzna")
        
#     def test9(self):
#         ask1 = read.parse_input("fact: (same Nestle ?Y)")
#         print(' Asking if', ask1)
#         answer = self.KB.kb_ask(ask1)
#         self.assertFalse(answer)
        
#     def test9(self):
#         ask1 = read.parse_input("fact: (friendly ?X)")
#         print(' Asking if', ask1)
#         answer = self.KB.kb_ask(ask1)
#         self.assertEqual(str(answer[0]), "?X : Uzna")
#         self.assertEqual(str(answer[1]), "?X : Hershey")
#         self.assertEqual(str(answer[2]), "?X : Ai")

        

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .....
# Asserting Fact('fact', Statement('isa', [Term(Constant('cube')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('pyramid')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('sphere')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('box')), Term(Constant('container'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('bigbox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('bigbox')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('littlebox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('littlebox')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid1')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid1')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid1')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid2')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid2')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid2')), Term(Constant('green'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid3')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid3')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid3')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid4')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid4')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid4')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube1')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube2')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube3')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube4')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('sphere1')), Term(Constant('sphere'))]), True, [], [], [])
# PARSE ERROR: input header hehe: not recognized.
# Asserting None
# fact:
# 	(isa cube block)
# 	 Asserted:       True
#
# fact:
# 	(isa pyramid block)
# 	 Asserted:       True
#
# fact:
# 	(isa sphere block)
# 	 Asserted:       True
#
# fact:
# 	(isa box container)
# 	 Asserted:       True
#
# fact:
# 	(inst bigbox box)
# 	 Asserted:       True
#
# fact:
# 	(size bigbox big)
# 	 Asserted:       True
#
# fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# fact:
# 	(inst littlebox box)
# 	 Asserted:       True
#
# fact:
# 	(size littlebox small)
# 	 Asserted:       True
#
# fact:
# 	(color littlebox blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid1 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid1 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid1 blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid2 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid2 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid2 green)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid3 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid3 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid3 red)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid4 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid4 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid4 red)
# 	 Asserted:       True
#
# fact:
# 	(inst cube1 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube2 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube3 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube4 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst sphere1 sphere)
# 	 Asserted:       True
#
#  Asking if fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# Asking Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('cube')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('pyramid')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('sphere')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('box')), Term(Constant('container'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('bigbox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('bigbox')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('littlebox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('littlebox')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid1')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid1')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid1')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid2')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid2')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid2')), Term(Constant('green'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid3')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid3')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid3')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid4')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid4')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid4')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube1')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube2')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube3')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube4')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('sphere1')), Term(Constant('sphere'))]), True, [], [], [])
# PARSE ERROR: input header hehe: not recognized.
# Asserting None
# fact:
# 	(isa cube block)
# 	 Asserted:       True
#
# fact:
# 	(isa pyramid block)
# 	 Asserted:       True
#
# fact:
# 	(isa sphere block)
# 	 Asserted:       True
#
# fact:
# 	(isa box container)
# 	 Asserted:       True
#
# fact:
# 	(inst bigbox box)
# 	 Asserted:       True
#
# fact:
# 	(size bigbox big)
# 	 Asserted:       True
#
# fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# fact:
# 	(inst littlebox box)
# 	 Asserted:       True
#
# fact:
# 	(size littlebox small)
# 	 Asserted:       True
#
# fact:
# 	(color littlebox blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid1 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid1 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid1 blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid2 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid2 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid2 green)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid3 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid3 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid3 red)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid4 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid4 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid4 red)
# 	 Asserted:       True
#
# fact:
# 	(inst cube1 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube2 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube3 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube4 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst sphere1 sphere)
# 	 Asserted:       True
#
#  Asking if fact:
# 	(color littlebox red)
# 	 Asserted:       True
#
# Asking Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('cube')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('pyramid')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('sphere')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('box')), Term(Constant('container'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('bigbox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('bigbox')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('littlebox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('littlebox')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid1')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid1')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid1')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid2')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid2')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid2')), Term(Constant('green'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid3')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid3')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid3')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid4')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid4')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid4')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube1')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube2')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube3')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube4')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('sphere1')), Term(Constant('sphere'))]), True, [], [], [])
# PARSE ERROR: input header hehe: not recognized.
# Asserting None
# fact:
# 	(isa cube block)
# 	 Asserted:       True
#
# fact:
# 	(isa pyramid block)
# 	 Asserted:       True
#
# fact:
# 	(isa sphere block)
# 	 Asserted:       True
#
# fact:
# 	(isa box container)
# 	 Asserted:       True
#
# fact:
# 	(inst bigbox box)
# 	 Asserted:       True
#
# fact:
# 	(size bigbox big)
# 	 Asserted:       True
#
# fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# fact:
# 	(inst littlebox box)
# 	 Asserted:       True
#
# fact:
# 	(size littlebox small)
# 	 Asserted:       True
#
# fact:
# 	(color littlebox blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid1 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid1 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid1 blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid2 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid2 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid2 green)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid3 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid3 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid3 red)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid4 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid4 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid4 red)
# 	 Asserted:       True
#
# fact:
# 	(inst cube1 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube2 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube3 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube4 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst sphere1 sphere)
# 	 Asserted:       True
#
#  Asking if fact:
# 	(color ?X red)
# 	 Asserted:       True
#
# Asking Fact('fact', Statement('color', [Term(Variable('?X')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('cube')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('pyramid')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('sphere')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('box')), Term(Constant('container'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('bigbox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('bigbox')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('littlebox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('littlebox')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid1')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid1')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid1')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid2')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid2')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid2')), Term(Constant('green'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid3')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid3')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid3')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid4')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid4')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid4')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube1')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube2')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube3')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube4')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('sphere1')), Term(Constant('sphere'))]), True, [], [], [])
# PARSE ERROR: input header hehe: not recognized.
# Asserting None
# fact:
# 	(isa cube block)
# 	 Asserted:       True
#
# fact:
# 	(isa pyramid block)
# 	 Asserted:       True
#
# fact:
# 	(isa sphere block)
# 	 Asserted:       True
#
# fact:
# 	(isa box container)
# 	 Asserted:       True
#
# fact:
# 	(inst bigbox box)
# 	 Asserted:       True
#
# fact:
# 	(size bigbox big)
# 	 Asserted:       True
#
# fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# fact:
# 	(inst littlebox box)
# 	 Asserted:       True
#
# fact:
# 	(size littlebox small)
# 	 Asserted:       True
#
# fact:
# 	(color littlebox blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid1 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid1 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid1 blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid2 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid2 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid2 green)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid3 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid3 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid3 red)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid4 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid4 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid4 red)
# 	 Asserted:       True
#
# fact:
# 	(inst cube1 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube2 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube3 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube4 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst sphere1 sphere)
# 	 Asserted:       True
#
#  Asking if fact:
# 	(color bigbox ?Y)
# 	 Asserted:       True
#
# Asking Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Variable('?Y'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('cube')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('pyramid')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('sphere')), Term(Constant('block'))]), True, [], [], [])
# Asserting Fact('fact', Statement('isa', [Term(Constant('box')), Term(Constant('container'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('bigbox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('bigbox')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('bigbox')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('littlebox')), Term(Constant('box'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('littlebox')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('littlebox')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid1')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid1')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid1')), Term(Constant('blue'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid2')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid2')), Term(Constant('small'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid2')), Term(Constant('green'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid3')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid3')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid3')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('pyramid4')), Term(Constant('pyramid'))]), True, [], [], [])
# Asserting Fact('fact', Statement('size', [Term(Constant('pyramid4')), Term(Constant('big'))]), True, [], [], [])
# Asserting Fact('fact', Statement('color', [Term(Constant('pyramid4')), Term(Constant('red'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube1')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube2')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube3')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('cube4')), Term(Constant('cube'))]), True, [], [], [])
# Asserting Fact('fact', Statement('inst', [Term(Constant('sphere1')), Term(Constant('sphere'))]), True, [], [], [])
# PARSE ERROR: input header hehe: not recognized.
# Asserting None
# fact:
# 	(isa cube block)
# 	 Asserted:       True
#
# fact:
# 	(isa pyramid block)
# 	 Asserted:       True
#
# fact:
# 	(isa sphere block)
# 	 Asserted:       True
#
# fact:
# 	(isa box container)
# 	 Asserted:       True
#
# fact:
# 	(inst bigbox box)
# 	 Asserted:       True
#
# fact:
# 	(size bigbox big)
# 	 Asserted:       True
#
# fact:
# 	(color bigbox red)
# 	 Asserted:       True
#
# fact:
# 	(inst littlebox box)
# 	 Asserted:       True
#
# fact:
# 	(size littlebox small)
# 	 Asserted:       True
#
# fact:
# 	(color littlebox blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid1 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid1 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid1 blue)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid2 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid2 small)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid2 green)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid3 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid3 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid3 red)
# 	 Asserted:       True
#
# fact:
# 	(inst pyramid4 pyramid)
# 	 Asserted:       True
#
# fact:
# 	(size pyramid4 big)
# 	 Asserted:       True
#
# fact:
# 	(color pyramid4 red)
# 	 Asserted:       True
#
# fact:
# 	(inst cube1 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube2 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube3 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst cube4 cube)
# 	 Asserted:       True
#
# fact:
# 	(inst sphere1 sphere)
# 	 Asserted:       True
#
#  Asking if fact:
# 	(color ?X ?Y)
# 	 Asserted:       True
#
# Asking Fact('fact', Statement('color', [Term(Variable('?X')), Term(Variable('?Y'))]), True, [], [], [])
# ----------------------------------------------------------------------
# Ran 5 tests in 0.156s
#
# OK
